# %%
pip install cvzone
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for cvzone: filename=cvzone-1.6.1-py3-none-any.whl size=26310 sha256=3d5234de4ce42eefc7d0fd9a2a9eed6b83e199e8ec9368db53d72e1cec129957
#   Stored in directory: c:\users\shreeaansh goel\appdata\local\pip\cache\wheels\ab\36\ec\47be2d4e59dc4289e684d5b0dde54d1e72e51a614e57690e85
# Successfully built cvzone
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import cvzone
from cvzone.PoseModule import PoseDetector
import os

cap = cv2.VideoCapture(0)
detector = PoseDetector()

shirtFolderPath = r"C:\Users\Shreeaansh Goel\Downloads\Resources/Shirts"
listShirts = os.listdir(shirtFolderPath)

fixedRatio = 262 / 190 
shirtRatioHeightWidth = 581 / 440

imageNumber = 0  

imgButtonRight = cv2.imread(r"C:\Users\Shreeaansh Goel\Downloads\Resources/button.png", cv2.IMREAD_UNCHANGED)
imgButtonLeft = cv2.flip(imgButtonRight, 1)

counterRight = 0
counterLeft = 0

selectionSpeed = 10

while True:
    success, img = cap.read()
    img = detector.findPose(img)
    lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
    if lmList:
        lm11 = lmList[11][1:3]
        lm12 = lmList[12][1:3]
        
        imgShirt = cv2.imread(os.path.join(shirtFolderPath, listShirts[imageNumber]), cv2.IMREAD_UNCHANGED)

        widthOfShirt = int((lm11[0] - lm12[0]) * fixedRatio)
        imgShirt = cv2.resize(imgShirt, (widthOfShirt, int(widthOfShirt * shirtRatioHeightWidth)))
        currentScale = (lm11[0] - lm12[0]) / 190
        offset = int(44 * currentScale), int(48 * currentScale)

        try:
            img = cvzone.overlayPNG(img, imgShirt, (lm12[0] - offset[0], lm12[1] - offset[1]))
        except:
            pass

        img = cvzone.overlayPNG(img, imgButtonRight, (1074, 293))
        img = cvzone.overlayPNG(img, imgButtonLeft, (72, 293))

        if lmList[16][1] < 300:
            counterRight += 1
            cv2.ellipse(img, (139, 360), (66, 66), 0, 0,
                        counterRight * selectionSpeed, (0, 255, 0), 20)

            if counterRight * selectionSpeed > 360:
                counterRight = 0
                if imageNumber < len(listShirts) - 1:
                    imageNumber += 1
        elif lmList[15][1] > 900:
            counterLeft += 1
            cv2.ellipse(img, (1138, 360), (66, 66), 0, 0,
                        counterLeft * selectionSpeed, (0, 255, 0), 20)
            if counterLeft * selectionSpeed > 360:
                counterLeft = 0
                if imageNumber > 0:
                    imageNumber -= 1

        else:
            counterRight = 0
            counterLeft = 0

    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 44
#      42 # Điều chỉnh lại kích thước shirt cho vừa khung hình
#      43 widthOfShirt = int((lm11[0] - lm12[0]) * fixedRatio)
# ---> 44 imgShirt = cv2.resize(imgShirt, (widthOfShirt, int(widthOfShirt * shirtRatioHeightWidth)))
#      45 currentScale = (lm11[0] - lm12[0]) / 190
#      46 offset = int(44 * currentScale), int(48 * currentScale)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4155: error: (-215:Assertion failed) inv_scale_x > 0 in function 'cv::resize'

# %%
import os

import cvzone
import cv2
from cvzone.PoseModule import PoseDetector

cap = cv2.VideoCapture(0)
detector = PoseDetector()

shirtFolderPath = r"C:\Users\Shreeaansh Goel\Downloads\Resources\Shirts"
listShirts = os.listdir(shirtFolderPath)

fixedRatio = 262 / 190  
shirtRatioHeightWidth = 581 / 440
imageNumber = 0
imgButtonRight = cv2.imread(r"C:\Users\Shreeaansh Goel\Downloads\Resources\button.png", cv2.IMREAD_UNCHANGED)
imgButtonLeft = cv2.flip(imgButtonRight, 1)
counterRight = 0
counterLeft = 0
selectionSpeed = 10

while True:
    success, img = cap.read()
    img = detector.findPose(img)
    # img = cv2.flip(img,1)
    lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
    if lmList:
        # center = bboxInfo["center"]
        lm11 = lmList[11][1:3]
        lm12 = lmList[12][1:3]
        imgShirt = cv2.imread(os.path.join(shirtFolderPath, listShirts[imageNumber]), cv2.IMREAD_UNCHANGED)

        widthOfShirt = int(max(0, (lm11[0] - lm12[0]) * fixedRatio))

        print(widthOfShirt)
        imgShirt = cv2.resize(imgShirt, (widthOfShirt, int(widthOfShirt * shirtRatioHeightWidth)))
        currentScale = (lm11[0] - lm12[0]) / 190
        offset = int(44 * currentScale), int(48 * currentScale)

        try:
            img = cvzone.overlayPNG(img, imgShirt, (lm12[0] - offset[0], lm12[1] - offset[1]))
        except:
            pass

        img = cvzone.overlayPNG(img, imgButtonRight, (1074, 293))
        img = cvzone.overlayPNG(img, imgButtonLeft, (72, 293))

        if lmList[16][1] < 300:
            counterRight += 1
            cv2.ellipse(img, (139, 360), (66, 66), 0, 0,
                        counterRight * selectionSpeed, (0, 255, 0), 20)
            if counterRight * selectionSpeed > 360:
                counterRight = 0
                if imageNumber < len(listShirts) - 1:
                    imageNumber += 1
        elif lmList[15][1] > 900:
            counterLeft += 1
            cv2.ellipse(img, (1138, 360), (66, 66), 0, 0,
                        counterLeft * selectionSpeed, (0, 255, 0), 20)
            if counterLeft * selectionSpeed > 360:
                counterLeft = 0
                if imageNumber > 0:
                    imageNumber -= 1

        else:
            counterRight = 0
            counterLeft = 0

    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 24
#      22 while True:
#      23     success, img = cap.read()
# ---> 24     img = detector.findPose(img)
#      25     # img = cv2.flip(img,1)
#      26     lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
#
# File E:\anaconda\Lib\site-packages\cvzone\PoseModule.py:57, in PoseDetector.findPose(self, img, draw)
#      50 def findPose(self, img, draw=True):
#      51     """
#      52     Find the pose landmarks in an Image of BGR color space.
#      53     :param img: Image to find the pose in.
#      54     :param draw: Flag to draw the output on the image.
#      55     :return: Image with or without drawings
#      56     """
# ---> 57     imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      58     self.results = self.pose.process(imgRGB)
# ...

# %%
import os
#code1extras
import cvzone
import cv2
from cvzone.PoseModule import PoseDetector

cap = cv2.VideoCapture(r"C:\Users\Shreeaansh Goel\Downloads\Resources/Videos/1.mp4")
detector = PoseDetector()

shirtFolderPath = r"C:\Users\Shreeaansh Goel\Downloads\Resources/Shirts"
listShirts = os.listdir(shirtFolderPath)

fixedRatio = 262 / 190 
shirtRatioHeightWidth = 581 / 440
imageNumber = 0
imgButtonRight = cv2.imread(r"C:\Users\Shreeaansh Goel\Downloads\Resources/button.png", cv2.IMREAD_UNCHANGED)
imgButtonLeft = cv2.flip(imgButtonRight, 1)
counterRight = 0
counterLeft = 0
selectionSpeed = 10

while True:
    success, img = cap.read()
    img = detector.findPose(img)
   
    lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
    if lmList:
      
        lm11 = lmList[11][1:3]
        lm12 = lmList[12][1:3]
        imgShirt = cv2.imread(os.path.join(shirtFolderPath, listShirts[imageNumber]), cv2.IMREAD_UNCHANGED)

        widthOfShirt = int((lm11[0] - lm12[0]) * fixedRatio)
        print(widthOfShirt)
        imgShirt = cv2.resize(imgShirt, (widthOfShirt, int(widthOfShirt * shirtRatioHeightWidth)))
        currentScale = (lm11[0] - lm12[0]) / 190
        offset = int(44 * currentScale), int(48 * currentScale)

        try:
            img = cvzone.overlayPNG(img, imgShirt, (lm12[0] - offset[0], lm12[1] - offset[1]))
        except:
            pass

        img = cvzone.overlayPNG(img, imgButtonRight, (1074, 293))
        img = cvzone.overlayPNG(img, imgButtonLeft, (72, 293))

        if lmList[16][1] < 300:
            counterRight += 1
            cv2.ellipse(img, (139, 360), (66, 66), 0, 0,
                        counterRight * selectionSpeed, (0, 255, 0), 20)
            if counterRight * selectionSpeed > 360:
                counterRight = 0
                if imageNumber < len(listShirts) - 1:
                    imageNumber += 1
        elif lmList[15][1] > 900:
            counterLeft += 1
            cv2.ellipse(img, (1138, 360), (66, 66), 0, 0,
                        counterLeft * selectionSpeed, (0, 255, 0), 20)
            if counterLeft * selectionSpeed > 360:
                counterLeft = 0
                if imageNumber > 0:
                    imageNumber -= 1

        else:
            counterRight = 0
            counterLeft = 0

    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# -11
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[1], line 35
#      33 widthOfShirt = int((lm11[0] - lm12[0]) * fixedRatio)
#      34 print(widthOfShirt)
# ---> 35 imgShirt = cv2.resize(imgShirt, (widthOfShirt, int(widthOfShirt * shirtRatioHeightWidth)))
#      36 currentScale = (lm11[0] - lm12[0]) / 190
#      37 offset = int(44 * currentScale), int(48 * currentScale)
#
# error: OpenCV(4.9.0) D:\a\opencv-python\opencv-python\opencv\modules\imgproc\src\resize.cpp:4155: error: (-215:Assertion failed) inv_scale_x > 0 in function 'cv::resize'

# %%
import cvzone
#code2extras
import cv2
import os 
from cvzone.PoseModule import PoseDetector

cap = cv2.VideoCapture(0)
detector = PoseDetector()
""" FIND THE ROOT DIRECTORTY TO CONVERT THE IMAGES INTO LIST """
shirtFolderPath =  r"C:\Users\Shreeaansh Goel\Downloads\Resources/Shirts"
""" GETTING THE LIST INTO THE PATH  """
listShirts = os.listdir(shirtFolderPath)
""" PRINT THE LIST """

fixedRatio = 262 / 190 
shirtRatioHeightWidth = 581 / 440 
imageNumber = 0
imgButtonRight = cv2.imread(r"C:\Users\Shreeaansh Goel\Downloads\Resources/button.png", cv2.IMREAD_UNCHANGED)
imgButtonLeft = cv2.flip(imgButtonRight, 1)
counterRight = 0
counterLeft = 0
selectionSpeed = 10

while True:
    success, img = cap.read()
    img = detector.findPose(img)
   
    lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
    if lmList:
     
       
        landMark11 = lmList[11][1:3]
        landMark12 = lmList[12][1:3]
        imgShirt = cv2.imread(os.path.join(shirtFolderPath, listShirts[imageNumber]), cv2.IMREAD_UNCHANGED)

        imgShirt = cv2.resize(imgShirt,(0,0), None,0.5,0.5)
        
        currentScale = (landMark11[0] - landMark12[0]) / 190

        offset = int(44 * currentScale), int(48 * currentScale)
        try:
            img = cvzone.overlayPNG(img, imgShirt, (landMark12[0] - offset[0], landMark12[1] - offset[1]))
        except:
            pass

        img = cvzone.overlayPNG(img, imgButtonRight, (1074,293))
        img = cvzone.overlayPNG(img, imgButtonLeft, (72,293))

        if lmList[16][1] < 300:
            counterRight += 1
            cv2.ellipse(img, (139,360),(66,66),0,0,counterRight*selectionSpeed,(0,255,0),20)
            if counterRight*selectionSpeed>360:
                counterRight = 0
                imageNumber +=1
        else:
            counterRight = 0
            counterLeft = 0



    cv2.imshow("Image", img)
    cv2.waitKey(1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 34
#      32 landMark12 = lmList[12][1:3]
#      33 """ PUT THE PATH AND THE IMAGES TOGETHER IN imgShirt VARIABLE  """
# ---> 34 imgShirt = cv2.imread(os.path.join(shirtFolderPath, listShirts[imageNumber]), cv2.IMREAD_UNCHANGED)
#      36 imgShirt = cv2.resize(imgShirt,(0,0), None,0.5,0.5)
#      38 """ CURRENT SCALE IT IS THE WIDTH
#      39 FROM THE 11 AND 12 LANDMARK """
#
# IndexError: list index out of range

# %%
import os
import cvzone
import cv2
from cvzone.PoseModule import PoseDetector

cap = cv2.VideoCapture(r"C:\Users\Shreeaansh Goel\Pictures\Camera Roll")
detector = PoseDetector()

shirtFolderPath = r"C:\Users\Shreeaansh Goel\Downloads\Resources/Shirts"
listShirts = os.listdir(shirtFolderPath)
fixedRatio = 262 / 190  
shirtRatioHeightWidth = 581 / 440
imageNumber = 0
imgButtonRight = cv2.imread(r"C:\Users\Shreeaansh Goel\Downloads\Resources/button.png", cv2.IMREAD_UNCHANGED)
imgButtonLeft = cv2.flip(imgButtonRight, 1)
counterRight = 0
counterLeft = 0
selectionSpeed = 10

while True:
    success, img = cap.read()
    img = detector.findPose(img)
    lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
    
    if lmList:
        upper_body_landmarks = [lmList[i][1:3] for i in [11, 12, 13, 14, 15]]
        if all(landmark[0] != 0 and landmark[1] != 0 for landmark in upper_body_landmarks):
            avg_position = (sum(landmark[0] for landmark in upper_body_landmarks) / len(upper_body_landmarks),
                            sum(landmark[1] for landmark in upper_body_landmarks) / len(upper_body_landmarks))
            
            imgShirt = cv2.imread(os.path.join(shirtFolderPath, listShirts[imageNumber]), cv2.IMREAD_UNCHANGED)
            imgShirt = cv2.resize(imgShirt, (0, 0), None, 0.5, 0.5)
            
            currentScale = (lmList[11][1] - lmList[12][1]) / 190
            
            offset = (int(44 * currentScale), int(48 * currentScale))
            
            try:
                img = cvzone.overlayPNG(img, imgShirt, (int(avg_position[0]) - offset[0], int(avg_position[1]) - offset[1]))
            except:
                pass
        
        img = cvzone.overlayPNG(img, imgButtonRight, (1074, 293))
        img = cvzone.overlayPNG(img, imgButtonLeft, (72, 293))
        
        if lmList[16][1] < 300:
            counterRight += 1
            cv2.ellipse(img, (139, 360), (66, 66), 0, 0,
                        counterRight * selectionSpeed, (0, 255, 0), 20)
            if counterRight * selectionSpeed > 360:
                counterRight = 0
                if imageNumber < len(listShirts) - 1:
                    imageNumber += 1
        elif lmList[15][1] > 900:
            counterLeft += 1
            cv2.ellipse(img, (1138, 360), (66, 66), 0, 0,
                        counterLeft * selectionSpeed, (0, 255, 0), 20)
            if counterLeft * selectionSpeed > 360:
                counterLeft = 0
                if imageNumber > 0:
                    imageNumber -= 1

    cv2.imshow("Image", img)
    
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[4], line 22
#      20 while True:
#      21     success, img = cap.read()
# ---> 22     img = detector.findPose(img)
#      23     lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
#      25     if lmList:
#      26         # Get the landmarks of interest (neck, shoulders, etc.)
#
# File E:\anaconda\Lib\site-packages\cvzone\PoseModule.py:57, in PoseDetector.findPose(self, img, draw)
#      50 def findPose(self, img, draw=True):
#      51     """
#      52     Find the pose landmarks in an Image of BGR color space.
#      53     :param img: Image to find the pose in.
#      54     :param draw: Flag to draw the output on the image.
#      55     :return: Image with or without drawings
#      56     """
# ---> 57     imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# Cell In[3], line 22
#      20 while True:
#      21     success, img = cap.read()
# ---> 22     img = detector.findPose(img)
#      23     lmList, bboxInfo = detector.findPosition(img, bboxWithHands=False, draw=False)
#      25     if lmList:
#      26         # Get the landmarks of interest (neck, shoulders, etc.)
#
# File E:\anaconda\Lib\site-packages\cvzone\PoseModule.py:57, in PoseDetector.findPose(self, img, draw)
#      50 def findPose(self, img, draw=True):
#      51     """
#      52     Find the pose landmarks in an Image of BGR color space.
#      53     :param img: Image to find the pose in.
#      54     :param draw: Flag to draw the output on the image.
#      55     :return: Image with or without drawings
#      56     """
# ---> 57     imgRGB = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# ...
